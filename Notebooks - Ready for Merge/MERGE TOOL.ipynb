# %%
#pip install nbmerge
# Out:
# ...
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6404 sha256=f046b614d6fab897599487d4f2a8d404bcd56afc30bdf03b0156cd4a75f9724a
#   Stored in directory: /root/.cache/pip/wheels/93/0c/59/ac91905c182ce43c4f39a50b5381c9485049cfe913237872ff
# Successfully built nbmerge
# ...

# %%
nb1 = '/content/drive/My Drive/Colab Notebooks/3251 Statistics (UW)/FINAL GROUP PROJECT/Understanding-Toronto-Shelters/Notebooks - Ready for Merge/VN_data_prep-FOR_MERGE.ipynb'
nb2 = '/content/drive/My Drive/Colab Notebooks/3251 Statistics (UW)/FINAL GROUP PROJECT/Understanding-Toronto-Shelters/Notebooks - Ready for Merge/VN_Cap_vs_Occ-FOR_MERGE.ipynb'
nb3 = ''
nb4 = ''
#%reset-f
#!cd '/content/drive/My Drive/Colab Notebooks/3251 Statistics (UW)/FINAL GROUP PROJECT/Understanding-Toronto-Shelters/Notebooks - Ready for Merge/'
# !nbmerge VN_data_prep-FOR_MERGE.ipynb VN_Cap_vs_Occ-FOR_MERGE.ipynb Team_Assignment-Weather-FOR_MERGE.ipynb CPI_vs_Occupancy_Analysis-FOR_MERGE.ipynb > merged-7.ipynb
#!nbmerge x
print('-----\nDONE.\n-----')
# !ls
# Out:
# -----
# DONE.
# -----
# CPI_vs_Occupancy_Analysis-FOR_MERGE.ipynb
# drive
# merged-3.ipynb
# merged-4.ipynb
# merged-5a.ipynb
# merged-5b.ipynb
# merged-6.ipynb
# merged-7.ipynb
# sample_data
# Team_Assignment-Weather-FOR_MERGE.ipynb
# VN_Cap_vs_Occ-FOR_MERGE.ipynb
# VN_data_prep-FOR_MERGE.ipynb

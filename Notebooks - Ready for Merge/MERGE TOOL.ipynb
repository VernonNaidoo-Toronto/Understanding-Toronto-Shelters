# %%
pip install nbmerge
# Out:
# ...
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6404 sha256=4cb026bf9436b6999d57941cfda38d72d5a4d4eb550ef5656eb979d29a2ea834
#   Stored in directory: /root/.cache/pip/wheels/93/0c/59/ac91905c182ce43c4f39a50b5381c9485049cfe913237872ff
# Successfully built nbmerge
# ...

# %%
# !nbmerge temp1.ipynb temp2.ipynb > merged.ipynb
